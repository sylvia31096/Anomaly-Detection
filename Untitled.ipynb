# %%
import pandas as pd
from matplotlib import pyplot as plt
from fbprophet import Prophet
from datetime import datetime
from sklearn import preprocessing
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold,GridSearchCV
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.neighbors import LocalOutlierFactor
from mlxtend.regressor import StackingRegressor
# %matplotlib inline

# %% [markdown]
# Load the dataset

# %%
successfulVends_raw = pd.read_csv("successfulVENDS2019.csv")

loan_raw = pd.read_csv("loan2019.csv")

# %% [markdown]
# Rename columns for uniformity

# %%
successfulVends_raw= successfulVends_raw.rename(index=str,columns={"transamount":"amount","systemtranstime":"time"})

# %% [markdown]
# Extract account number,amount and timestamp

# %%
successfulVends= successfulVends_raw[['address','amount','time']]

# %% [markdown]
# Convert to datetime type

# %%
successfulVends['time']=pd.to_datetime(successfulVends.time)
successfulVends= successfulVends[successfulVends['address']!='notfound']

# %% [markdown]
# Retrieve train and test data

# %%
train = successfulVends[successfulVends.time.dt.month<3]
test = successfulVends[successfulVends.time.dt.month==3]

# %% [markdown]
# Group by each account

# %%
successfulVends_grouped = train.groupby([train.address,train.time.dt.date]).agg({"amount": ['count','mean']})
successfulVends_grouped.columns = successfulVends_grouped.columns.droplevel(0)

successfulVends_grouped.head()
# Out:
#                      count    mean
# address  time
# 0074836  2019-02-14      2   300.0
# 100      2019-02-17      1   200.0
# 11705589 2019-01-28      1   425.0
#          2019-02-24      1  1925.0
# 12926391 2019-02-06      1   500.0

# %%
successfulVends_trans_grouped = train.groupby([train.time.dt.date]).count()

successfulVends_trans_grouped.drop(['address','time'],inplace=True,axis=1)
successfulVends_trans_grouped.reset_index(inplace=True)
successfulVends_trans_grouped['time'] = pd.to_datetime(successfulVends_trans_grouped.time)
successfulVends_trans_grouped.head()
# Out:
#         time  amount
# 0 2019-01-01       1
# 1 2019-01-02     893
# 2 2019-01-03     345
# 3 2019-01-04     828
# 4 2019-01-05       3

# %%
df = successfulVends_grouped.reset_index(level=1)
df['time'] = pd.to_datetime(df.time)
df = df.merge(successfulVends_trans_grouped, on='time', how='left')
df.head()
# Out:
#         time  count    mean  amount
# 0 2019-02-14      2   300.0     797
# 1 2019-02-17      1   200.0     829
# 2 2019-01-28      1   425.0     873
# 3 2019-02-24      1  1925.0     995
# 4 2019-02-06      1   500.0     953

# %%
from mpl_toolkits import mplot3d
plt.rcParams['figure.figsize']=[19,7]
fig = plt.figure()
ax = plt.axes(projection="3d")
x= df['count']
y=df['mean']
z=df.time.dt.day
c=df.amount
ax.scatter3D(x, y,z,c=c, cmap='hsv')
#successfulVends_grouped.plot.ax.scatter3D(y='count',x='mean',z=successfulVends_grouped.index.get_level_values(1).hour)

# %%
df['count'].std()
# Out:
# 0.30611280158184268

# %% [markdown]
# Is there any relationships between the multiple transactions and system being busy or "failure"?

# %%
successfulVends_grouped[successfulVends_grouped['count']>50]
# Out:
# Empty DataFrame
# Columns: [count, mean]
# Index: []
