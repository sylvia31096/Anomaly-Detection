# %% [markdown]
# This notebook has regression models to predict number of transactions given the timestamp.
#
# The data is based on an hourly basis (for accuracy issues)

# %% [markdown]
# # Deposit

# %% [markdown]
# Import libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from sklearn import preprocessing
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from fbprophet import Prophet
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Get the dataset

# %%
deposit_raw = pd.read_csv("deposit2019.csv")
successfulVends_raw = pd.read_csv("successfulVENDS2019.csv")

# %% [markdown]
# Retrieve columns and rename columns

# %%
deposit = deposit_raw[["systemtranstime","transamount"]]

deposit= deposit.rename(index=str,columns={"transamount":"amount","systemtranstime":"time"})

# %% [markdown]
# Convert time to datetime

# %%
deposit['time']=pd.to_datetime(deposit.time)

# %% [markdown]
# Normalization function

# %%
def normalize(z):
    x = z
    x = x.values #returns a numpy array
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(np.vstack(x))
    return x_scaled

# %% [markdown]
# Get number of transactions hourly

# %%
deposit_hour = deposit.resample('60min', on='time').count().drop('time',axis=1)

# %%
#deposit_hour = deposit

# %% [markdown]
# Normalize the number of transactions

# %%
deposit_hour['amount']=normalize(deposit_hour['amount'])

# %% [markdown]
# Get the train and test dataset
# train: is the first 2 months
# test: is the third month

# %%
train = deposit_hour[deposit_hour.index.month<3]
test = deposit_hour[deposit_hour.index.month==3]

# %% [markdown]
# ## STL Decomposition

# %%
plt.rcParams['figure.figsize']=[19,7]
res = seasonal_decompose(train,model='additive')
resplot = res.plot()

# %% [markdown]
# It captures the seasonality.

# %% [markdown]
# Renaming column to be able to pass to fb prophet's algorithm

# %%
df = deposit_hour.reset_index().rename(index=str,columns={"amount":"y","time":"ds"})
train_fb = df[df.ds.dt.month<3]
test_fb = df[df.ds.dt.month==3]

# %% [markdown]
# Create instance of prophet and fit data

# %%
m = Prophet()
m.fit(train_fb)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# Predict up to the following month even after two months passed

# %%
future = m.make_future_dataframe(periods=616,freq='H')
future.tail()
# Out:
#                       ds
# 2027 2019-03-26 11:00:00
# 2028 2019-03-26 12:00:00
# 2029 2019-03-26 13:00:00
# 2030 2019-03-26 14:00:00
# 2031 2019-03-26 15:00:00

# %% [markdown]
# Make predictions

# %%
forecast = m.predict(future)
forecast.tail()
# Out:
#                       ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 2027 2019-03-26 11:00:00  0.052571   -0.034706    0.123573     0.008548
# 2028 2019-03-26 12:00:00  0.052580   -0.047147    0.110141     0.008426
# 2029 2019-03-26 13:00:00  0.052589   -0.039329    0.119847     0.008303
# 2030 2019-03-26 14:00:00  0.052598   -0.014220    0.145630     0.008180
# 2031 2019-03-26 15:00:00  0.052607    0.030413    0.182057     0.008027
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 2027     0.097921       -0.010676             -0.010676             -0.010676
# 2028     0.098000       -0.017482             -0.017482             -0.017482
# 2029     0.098079       -0.011830             -0.011830             -0.011830
# 2030     0.098158        0.014311              0.014311              0.014311
# 2031     0.098237        0.052866              0.052866              0.052866
#
#          daily  daily_lower  daily_upper    weekly  weekly_lower  \
# 2027 -0.001158    -0.001158    -0.001158 -0.009518     -0.009518
# 2028 -0.007390    -0.007390    -0.007390 -0.010092     -0.010092
# 2029 -0.001198    -0.001198    -0.001198 -0.010632     -0.010632
# 2030  0.025438     0.025438     0.025438 -0.011128     -0.011128
# 2031  0.064437     0.064437     0.064437 -0.011571     -0.011571
#
#       weekly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 2027     -0.009518                   0.0                         0.0
# 2028     -0.010092                   0.0                         0.0
# 2029     -0.010632                   0.0                         0.0
# 2030     -0.011128                   0.0                         0.0
# 2031     -0.011571                   0.0                         0.0
#
#       multiplicative_terms_upper      yhat
# 2027                         0.0  0.041895
# 2028                         0.0  0.035098
# 2029                         0.0  0.040759
# 2030                         0.0  0.066909
# 2031                         0.0  0.105472

# %% [markdown]
# Show forecast

# %% [markdown]
# Get the r2 score of the train and test

# %%
#extract train only
forecast_train  = forecast[forecast.ds.dt.month<3]

r2_score(train_fb.y,forecast_train.yhat)
# Out:
# 0.46493678432187913

# %%
#extract test
forecast_test  = forecast[forecast.ds.dt.month==3]
r2_score(test_fb.y,forecast_test.yhat)
# Out:
# 0.38866610172552862

# %%
fig1 = m.plot(forecast)

# %% [markdown]
# ### Classification Trees

# %% [markdown]
# Breakdown timestamp to other features so as to pass it to regressors i.e hour,day and day of the week

# %%
deposit_hour['hour'] = deposit_hour.index.hour
deposit_hour['week'] =  deposit_hour.index.week
deposit_hour['month'] =  deposit_hour.index.month
deposit_hour['day_of_week'] =  deposit_hour.index.dayofweek
deposit_hour['previous_amount'] =  deposit_hour.amount.shift(1)
deposit_hour.head()
# Out:
#                        amount  hour  week  month  day_of_week  previous_amount
# time
# 2018-12-31 21:00:00  0.024719    21     1     12            0              NaN
# 2018-12-31 22:00:00  0.010112    22     1     12            0         0.024719
# 2018-12-31 23:00:00  0.012360    23     1     12            0         0.010112
# 2019-01-01 00:00:00  0.000000     0     1      1            1         0.012360
# 2019-01-01 01:00:00  0.006742     1     1      1            1         0.000000

# %% [markdown]
# Create a train and test dataset of the decomposed timestamp dataframe

# %%
train_decompose = deposit_hour[deposit_hour.index.month<3]
test_decompose = deposit_hour[deposit_hour.index.month==3]

# %% [markdown]
# Create train and test matrices without y column to pass to regression models

# %%
X_train = train_decompose.drop(columns=['amount']) 
X_test = test_decompose.drop(columns=['amount']) 

y_train = train_decompose.amount
y_test = test_decompose.amount

# %% [markdown]
# Import libraries for the model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
 
#these are the hyperparameters that yielded the best test results (no grid search)
clf = RandomForestRegressor(max_depth=7, random_state=15,n_estimators=22)
clf.fit(X_train, y_train) 

y_ = clf.predict(X_test)
y_pred = clf.predict(X_train)

#get r_score
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.924320608399 			 0.76766477567

# %% [markdown]
# Creating dataframe to plot predictions and actual with ease

# %%
#using test
predictions= test
predictions['predictions'] = y_

# %%
predictions.plot()

# %%
#using train
pred= train
pred['predictions'] = y_pred
pred.plot()

# %% [markdown]
# ## KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

#number of neighbours with best results (no grid search)
neigh = KNeighborsRegressor(n_neighbors=50)
neigh.fit(X_train, y_train) 
    
y_ = neigh.predict(X_test)
y_pred = neigh.predict(X_train)

#r2_score for train and test
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.496190344285 			 0.462157875761

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

#no tuning of hyperparameters
reg = LinearRegression().fit(X_train, y_train)
y_ = reg.predict(X_test)
y_pred = reg.predict(X_train)

#r2_score for train and test
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.708831462787 			 0.711755531432

# %% [markdown]
# ## Stack Regressor

# %%
#Ensemble(stacking) for regressors (not sure how it works)
from mlxtend.regressor import StackingRegressor

#use the three algorithms
lr = LinearRegression()
rfr = RandomForestRegressor(max_depth=8, random_state=16,n_estimators=23)

neigh = KNeighborsRegressor(n_neighbors=35)
stregr = StackingRegressor(regressors=[rfr, lr, neigh], 
                           meta_regressor=neigh)

# Training the stacking classifier

stregr.fit(X_train, y_train) 

y_ = stregr.predict(X_test)
y_pred = stregr.predict(X_train)

#r2_score for train and test
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.803633341523 			 0.830192444785

# %%
#using test
predictions= test
predictions['predictions'] = y_
predictions.plot()

# %% [markdown]
# ## Successful Vends

# %%
successfulVends = successfulVends_raw[["time","amount"]]

# %% [markdown]
# Convert time to datetime

# %%
successfulVends['time']=pd.to_datetime(successfulVends.time)

# %% [markdown]
# Get number of transactions hourly

# %%
successfulVends_hour = successfulVends.resample('60min', on='time').count().drop('time',axis=1)

# %% [markdown]
# Normalize the values

# %%
successfulVends_hour['amount']=normalize(successfulVends_hour['amount'])

# %% [markdown]
# Get the train and test dataset
# train: is the first 2 months
# test: is the third month

# %%
train = successfulVends_hour[successfulVends_hour.index.month<3]
test = successfulVends_hour[successfulVends_hour.index.month==3]

# %% [markdown]
# ## STL Decomposition

# %%
plt.rcParams['figure.figsize']=[19,7]
res = seasonal_decompose(train,model='additive')
resplot = res.plot()

# %% [markdown]
# It captures the seasonality.

# %% [markdown]
# Renaming column to be able to pass to fb prophet's algorithm

# %%
df = successfulVends_hour.reset_index().rename(index=str,columns={"amount":"y","time":"ds"})
train_fb = df[df.ds.dt.month<3]
test_fb = df[df.ds.dt.month==3]

# %% [markdown]
# Create instance of prophet and fit data

# %%
m = Prophet()
m.fit(train_fb)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# Predict up to the following month even after two months passed

# %%
future = m.make_future_dataframe(periods=616,freq='H')
future.tail()
# Out:
#                       ds
# 2021 2019-03-26 11:00:00
# 2022 2019-03-26 12:00:00
# 2023 2019-03-26 13:00:00
# 2024 2019-03-26 14:00:00
# 2025 2019-03-26 15:00:00

# %% [markdown]
# Make predictions

# %%
forecast = m.predict(future)
forecast.tail()
# Out:
#                       ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 2021 2019-03-26 11:00:00  0.030032   -0.076806    0.135918     0.009684
# 2022 2019-03-26 12:00:00  0.030007   -0.088509    0.126382     0.009609
# 2023 2019-03-26 13:00:00  0.029983   -0.082097    0.125202     0.009539
# 2024 2019-03-26 14:00:00  0.029959   -0.054594    0.166532     0.009475
# 2025 2019-03-26 15:00:00  0.029935   -0.001695    0.197495     0.009398
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 2021     0.050562        0.003583              0.003583              0.003583
# 2022     0.050581       -0.008569             -0.008569             -0.008569
# 2023     0.050594       -0.006010             -0.006010             -0.006010
# 2024     0.050607        0.022422              0.022422              0.022422
# 2025     0.050608        0.066000              0.066000              0.066000
#
#          daily  daily_lower  daily_upper    weekly  weekly_lower  \
# 2021  0.016523     0.016523     0.016523 -0.012940     -0.012940
# 2022  0.003898     0.003898     0.003898 -0.012467     -0.012467
# 2023  0.005933     0.005933     0.005933 -0.011943     -0.011943
# 2024  0.033797     0.033797     0.033797 -0.011375     -0.011375
# 2025  0.076767     0.076767     0.076767 -0.010768     -0.010768
#
#       weekly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 2021     -0.012940                   0.0                         0.0
# 2022     -0.012467                   0.0                         0.0
# 2023     -0.011943                   0.0                         0.0
# 2024     -0.011375                   0.0                         0.0
# 2025     -0.010768                   0.0                         0.0
#
#       multiplicative_terms_upper      yhat
# 2021                         0.0  0.033614
# 2022                         0.0  0.021438
# 2023                         0.0  0.023974
# 2024                         0.0  0.052382
# 2025                         0.0  0.095935

# %% [markdown]
# Show forecast

# %% [markdown]
# Get the r2 score of the train and test

# %%
#extract train only
forecast_train  = forecast[forecast.ds.dt.month<3]

r2_score(train_fb.y,forecast_train.yhat)
# Out:
# 0.29504049516204711

# %%
#extract test
forecast_test  = forecast[forecast.ds.dt.month==3]
r2_score(test_fb.y,forecast_test.yhat)
# Out:
# 0.11748323647712622

# %%
fig1 = m.plot(forecast)

# %% [markdown]
# ### Classification Trees

# %% [markdown]
# Breakdown timestamp to other features so as to pass it to regressors i.e hour,day and day of the week

# %%
successfulVends_hour['hour'] = successfulVends_hour.index.hour
successfulVends_hour['week'] =  successfulVends_hour.index.week
successfulVends_hour['month'] =  successfulVends_hour.index.month
successfulVends_hour['day_of_week'] =  successfulVends_hour.index.dayofweek
successfulVends_hour['previous_amount'] =  successfulVends_hour.amount.shift(1)

successfulVends_hour=  successfulVends_hour.dropna()

successfulVends_hour.head()
# Out:
#                      amount  hour  week  month  day_of_week  previous_amount
# time
# 2019-01-01 07:00:00     0.0     7     1      1            1         0.001353
# 2019-01-01 08:00:00     0.0     8     1      1            1         0.000000
# 2019-01-01 09:00:00     0.0     9     1      1            1         0.000000
# 2019-01-01 10:00:00     0.0    10     1      1            1         0.000000
# 2019-01-01 11:00:00     0.0    11     1      1            1         0.000000

# %% [markdown]
# Create a train and test dataset of the decomposed timestamp dataframe

# %%
train_decompose = successfulVends_hour[successfulVends_hour.index.month<3]
test_decompose = successfulVends_hour[successfulVends_hour.index.month==3]

# %% [markdown]
# Create train and test matrices without y column to pass to regression models

# %%
X_train = train_decompose.drop(columns=['amount']) 
X_test = test_decompose.drop(columns=['amount']) 

y_train = train_decompose.amount
y_test = test_decompose.amount

# %% [markdown]
# Import libraries for the model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
 
#these are the hyperparameters that yielded the best test results (no grid search)
clf = RandomForestRegressor(max_depth=7, random_state=15,n_estimators=22)
clf.fit(X_train, y_train) 

y_ = clf.predict(X_test)
y_pred = clf.predict(X_train)

#get r_score
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.702818236448 			 0.252474737558

# %% [markdown]
# Creating dataframe to plot predictions and actual with ease

# %%
#using test
predictions= test
predictions['predictions'] = y_

# %%
predictions.plot()

# %%
train.count()
# Out:
# amount    1410
# dtype: int64

# %%
#using train
pred= train[1:]
pred['predictions'] = y_pred
pred.plot()

# %%
pred

# %% [markdown]
# ## KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

#number of neighbours with best results (no grid search)
neigh = KNeighborsRegressor(n_neighbors=50)
neigh.fit(X_train, y_train) 
    
y_ = neigh.predict(X_test)
y_pred = neigh.predict(X_train)

#r2_score for train and test
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.346135559129 			 0.152127153277

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

#no tuning of hyperparameters
reg = LinearRegression().fit(X_train, y_train)
y_ = reg.predict(X_test)
y_pred = reg.predict(X_train)

#r2_score for train and test
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.374168243436 			 0.284546842637

# %% [markdown]
# ## Stack Regressor

# %%
#Ensemble(stacking) for regressors (not sure how it works)
from mlxtend.regressor import StackingRegressor

#use the three algorithms
lr = LinearRegression()
rfr = RandomForestRegressor(max_depth=8, random_state=16,n_estimators=23)

neigh = KNeighborsRegressor(n_neighbors=35)
stregr = StackingRegressor(regressors=[rfr, lr, neigh], 
                           meta_regressor=neigh)

# Training the stacking classifier

stregr.fit(X_train, y_train) 

y_ = stregr.predict(X_test)
y_pred = stregr.predict(X_train)

#r2_score for train and test
print(r2_score(y_train, y_pred),'\t\t\t',r2_score(y_test, y_))
# Out:
# 0.653552121425 			 0.315942353808

# %%
#using test
predictions= test
predictions['predictions'] = y_
predictions.plot()
